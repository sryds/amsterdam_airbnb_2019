# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.cluster import KMeans 
import pylab as pl

# %%
path = r'C:\Users\artoe\Documents\DataAnalytics\Data Immersion\Exercises\Achievement 6\data'

# %% [markdown]
# #### Prepare data for analysis

# %%
#import data
df_airbnb_complete = pd.read_csv(os.path.join(path,'listings_final.csv'), index_col=False)

# %%
df_airbnb_complete.columns
# Out:
# Index(['Unnamed: 0', 'id', 'listing_avg_price_year', 'name', 'street',
#        'neighbourhood', 'city', 'latitude', 'longitude', 'room_type',
#        'square_feet', 'availability_365', 'host_listings_count',
#        'review_scores_rating', 'review_scores_location', 'review_scores_value',
#        'review_scores_cleanliness', 'entire_home', 'private_room',
#        'shared_room', 'distance_from_center'],
#       dtype='object')

# %%
#creating a subset with data to be used 
df_sub = df_airbnb_complete[['listing_avg_price_year','review_scores_rating','review_scores_location','review_scores_value','review_scores_cleanliness','availability_365','distance_from_center', 'host_listings_count']]

# %%
df_sub.shape
# Out:
# (20030, 8)

# %%
df_sub.isnull().sum()
# Out:
# listing_avg_price_year       9344
# review_scores_rating         2639
# review_scores_location       2660
# review_scores_value          2659
# review_scores_cleanliness    2647
# availability_365                0
# distance_from_center            0
# host_listings_count             0
# dtype: int64

# %%
#the review score null rows can all be dropped for the purpose of this task, since they still make up only a small portion of the entire dataset
df_sub.dropna(inplace = True)
# Out:
# C:\Users\artoe\AppData\Local\Temp\ipykernel_18704\3770902085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub.dropna(inplace = True)

# %%
df_sub.shape
#the data is now only representing listings that are vacant for at least 1 day in the upcoming year, and have more than 0 reviews.
# Out:
# (9378, 8)

# %% [markdown]
# ##### Checking scale of data

# %%
df_sub.describe()
# Out:
#        listing_avg_price_year  review_scores_rating  review_scores_location  \
# count             9378.000000           9378.000000             9378.000000
# mean               174.738892             95.209106                9.470996
# std                172.250034              5.976804                0.677383
# min                 25.333333             20.000000                2.000000
# 25%                105.616033             93.000000                9.000000
# 50%                145.848178             97.000000               10.000000
# 75%                201.234709             99.000000               10.000000
# max               8500.000000            100.000000               10.000000
#
#        review_scores_value  review_scores_cleanliness  availability_365  \
# count          9378.000000                9378.000000       9378.000000
# mean              9.185007                   9.533163        110.070271
# std               0.734007                   0.758316        118.029393
# min               2.000000                   2.000000          1.000000
# 25%               9.000000                   9.000000         13.000000
# 50%               9.000000                  10.000000         60.000000
# 75%              10.000000                  10.000000        180.000000
# max              10.000000                  10.000000        365.000000
#
#        distance_from_center  host_listings_count
# count           9378.000000          9378.000000
# mean               2.663088             2.954255
# std                1.625358            14.944337
# min                0.022259             1.000000
# 25%                1.620553             1.000000
# 50%                2.407557             1.000000
# 75%                3.238718             2.000000
# max               11.326607           208.000000

# %%
#calculate availability percent
df_sub['availability_percent'] = (df_sub['availability_365']/365)*100
# Out:
# C:\Users\artoe\AppData\Local\Temp\ipykernel_18704\3438893977.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['availability_percent'] = (df_sub['availability_365']/365)*100

# %%
#we can also multiply the distance from center by 1000 to show meters instead of km
df_sub['meters_from_center'] = df_sub['distance_from_center']*1000
# Out:
# C:\Users\artoe\AppData\Local\Temp\ipykernel_18704\80248965.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['meters_from_center'] = df_sub['distance_from_center']*1000

# %%
df_sub['review_scores_location_100'] = df_sub['review_scores_location']*10
# Out:
# C:\Users\artoe\AppData\Local\Temp\ipykernel_18704\850780599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['review_scores_location_100'] = df_sub['review_scores_location']*10

# %%
df_sub['review_scores_value_100'] = df_sub['review_scores_value']*10
# Out:
# C:\Users\artoe\AppData\Local\Temp\ipykernel_18704\3516812712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['review_scores_value_100'] = df_sub['review_scores_value']*10

# %%
df_sub['review_scores_cleanliness_100'] = df_sub['review_scores_cleanliness']*10
# Out:
# C:\Users\artoe\AppData\Local\Temp\ipykernel_18704\3482335888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['review_scores_cleanliness_100'] = df_sub['review_scores_cleanliness']*10

# %%
df_sub.describe().T
# Out:
#                                 count         mean          std        min  \
# listing_avg_price_year         9378.0   174.738892   172.250034  25.333333
# review_scores_rating           9378.0    95.209106     5.976804  20.000000
# review_scores_location         9378.0     9.470996     0.677383   2.000000
# review_scores_value            9378.0     9.185007     0.734007   2.000000
# review_scores_cleanliness      9378.0     9.533163     0.758316   2.000000
# availability_365               9378.0   110.070271   118.029393   1.000000
# distance_from_center           9378.0     2.663088     1.625358   0.022259
# host_listings_count            9378.0     2.954255    14.944337   1.000000
# availability_percent           9378.0    30.156239    32.336820   0.273973
# meters_from_center             9378.0  2663.087590  1625.358378  22.258728
# review_scores_location_100     9378.0    94.709959     6.773827  20.000000
# review_scores_value_100        9378.0    91.850075     7.340070  20.000000
# review_scores_cleanliness_100  9378.0    95.331627     7.583165  20.000000
#
#                                        25%          50%          75%  \
# listing_avg_price_year          105.616033   145.848178   201.234709
# review_scores_rating             93.000000    97.000000    99.000000
# review_scores_location            9.000000    10.000000    10.000000
# review_scores_value               9.000000     9.000000    10.000000
# review_scores_cleanliness         9.000000    10.000000    10.000000
# availability_365                 13.000000    60.000000   180.000000
# distance_from_center              1.620553     2.407557     3.238718
# host_listings_count               1.000000     1.000000     2.000000
# availability_percent              3.561644    16.438356    49.315068
# meters_from_center             1620.553198  2407.556655  3238.718171
# review_scores_location_100       90.000000   100.000000   100.000000
# review_scores_value_100          90.000000    90.000000   100.000000
# review_scores_cleanliness_100    90.000000   100.000000   100.000000
#
#                                         max
# listing_avg_price_year          8500.000000
# review_scores_rating             100.000000
# review_scores_location            10.000000
# review_scores_value               10.000000
# review_scores_cleanliness         10.000000
# availability_365                 365.000000
# distance_from_center              11.326607
# host_listings_count              208.000000
# availability_percent             100.000000
# meters_from_center             11326.606980
# review_scores_location_100       100.000000
# review_scores_value_100          100.000000
# review_scores_cleanliness_100    100.000000

# %%
#drop columns outside scale range
df_sub.drop(columns=['review_scores_location','review_scores_value','review_scores_cleanliness'], inplace=True)
# Out:
# C:\Users\artoe\AppData\Local\Temp\ipykernel_18704\3428799312.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub.drop(columns=['review_scores_location','review_scores_value','review_scores_cleanliness'], inplace=True)

# %%
df_sub.drop(columns='distance_from_center', inplace=True)
# Out:
# C:\Users\artoe\AppData\Local\Temp\ipykernel_18704\812725015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub.drop(columns='distance_from_center', inplace=True)

# %% [markdown]
# #### Determining number of clusters

# %%
#determining the number of clusters using the elbow method
num_cl = range(1, 10)
kmeans = [KMeans(n_clusters=i) for i in num_cl]

# %%
#calculate score
score = [kmeans[i].fit(df_sub).score(df_sub) for i in range(len(kmeans))]

# %%
score
# Out:
# [-25194619261.633827,
#  -10685836197.965109,
#  -4997239588.648141,
#  -3103497424.1510086,
#  -2259184973.096469,
#  -1805686058.1464934,
#  -1435290688.2605095,
#  -1185580829.1948233,
#  -1016683284.8747686]

# %%
#plot the scores
pl.plot(num_cl,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.show()

# %%
#the "elbow" appears at 3 clusters

# %% [markdown]
# #### Apply clustering to data

# %%
kmeans = KMeans(n_clusters = 3)

# %%
kmeans.fit(df_sub)
# Out:
# KMeans(n_clusters=3)

# %%
df_sub['clusters'] = kmeans.fit_predict(df_sub)
# Out:
# C:\Users\artoe\AppData\Local\Temp\ipykernel_18704\4169945.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['clusters'] = kmeans.fit_predict(df_sub)

# %%
#checking the cluster numbers and counts
df_sub['clusters'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 5    0
# Name: clusters, dtype: int32

# %%
df_sub['clusters'].value_counts()
# Out:
# clusters
# 1    4703
# 0    4080
# 2     595
# Name: count, dtype: int64

# %%
#plot the clusters for two variables: distance_from_center (x) and price (y)
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_sub['meters_from_center'], y=df_sub['listing_avg_price_year'], hue=kmeans.labels_, s=100) 
ax.grid(False) 
plt.xlabel('Distance from City Center (Meters)') 
plt.ylabel('Price') 
plt.show()

# %%
#plot the clusters for two variables: review score rating (x) and monthly_availability_percent (y)
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_sub['review_scores_rating'], y=df_sub['availability_percent'], hue=kmeans.labels_, s=100) 
ax.grid(False) 
plt.xlabel('Review Score Rating (out of 100)') 
plt.ylabel('Percent of the Year Available') 
plt.show()

# %%
#plot the clusters for two variables: meters from center (x) and monthly_availability_percent (y)
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_sub['meters_from_center'], y=df_sub['availability_percent'], hue=kmeans.labels_, s=100) 
ax.grid(False) 
plt.xlabel('Distance from City Center (Meters)') 
plt.ylabel('Percent Availability in the Year') 
plt.show()

# %%
#plot clusters for review scores rating and host listings count
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_sub['host_listings_count'], y=df_sub['review_scores_rating'], hue=kmeans.labels_, s=100) 
ax.grid(False) 
plt.xlabel('Number of Listings by Host') 
plt.ylabel('Review Scores Rating') 
plt.show()

# %%
#plot clusters for price and host listings count
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_sub['host_listings_count'], y=df_sub['listing_avg_price_year'], hue=kmeans.labels_, s=100) 
ax.grid(False) 
plt.xlabel('Number of Listings by Host') 
plt.ylabel('Average Listing Price') 
plt.show()

# %%
#plot clusters for review scores for cleanliness and host listings count
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=df_sub['host_listings_count'], y=df_sub['review_scores_cleanliness_100'], hue=kmeans.labels_, s=100) 
ax.grid(False) 
plt.xlabel('Number of Listings by Host') 
plt.ylabel('Review Scores for Cleanliness') 
plt.show()

# %% [markdown]
# #### Grouping by cluster, getting descriptive stats

# %%
df_sub.loc[df_sub['clusters'] == 2, 'cluster'] = 'cluster2'
df_sub.loc[df_sub['clusters'] == 1, 'cluster'] = 'cluster1'
df_sub.loc[df_sub['clusters'] == 0, 'cluster'] = 'cluster0'
# Out:
# C:\Users\artoe\AppData\Local\Temp\ipykernel_18704\2082677568.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub.loc[df_sub['clusters'] == 2, 'cluster'] = 'cluster2'

# %%
df_sub.groupby('cluster').agg({'listing_avg_price_year':['mean', 'median', 'min', 'max'], 
                         'review_scores_rating':['mean', 'median', 'min', 'max'], 
                         'availability_percent':['mean', 'median', 'min', 'max'],
                          'meters_from_center':['mean', 'median', 'min', 'max']}).T
# Out:
# cluster                           cluster0     cluster1      cluster2
# listing_avg_price_year mean     175.174182   174.979595    169.851487
#                        median   145.786262   146.250000    141.760638
#                        min       26.514469    25.333333     30.047619
#                        max     8000.000000  8500.000000    799.000000
# review_scores_rating   mean      95.301716    95.177546     94.823529
#                        median    97.000000    97.000000     97.000000
#                        min       20.000000    20.000000     50.000000
#                        max      100.000000   100.000000    100.000000
# availability_percent   mean      29.932984    30.418124     29.617129
#                        median    15.890411    16.986301     15.890411
#                        min        0.273973     0.273973      0.273973
#                        max      100.000000   100.000000    100.000000
# meters_from_center     mean    3276.305132  1544.734781   7297.853455
#                        median  3099.146398  1623.723216   7176.255508
#                        min     2411.867846    22.258728   5295.485390
#                        max     5284.478666  2411.667563  11326.606980

# %% [markdown]
# ##### The clusters neatly sort two of the variables, price and distance from center, into distinct categories. Cluster 1 contains the highest mean price and lowest mean distance values, while cluster 0 contains the lowest price and highest distance values. This indicates a strong negative correlation between rental price and a listing's distance from the city center.
# ##### Plotting price and distance from center shows that the highest price values are located closest to the city center. However, low price values can be found throughout all distance values.
# ##### Monthly availability and review scores, however, do not fall into any distinct groups, indicating that these two variables are not influenced by each other, nor by price or distance from center.

# %%
df_sub.to_csv(os.path.join(path, 'cluster_data.csv'))

# %%
df_sub.shape
# Out:
# (9378, 11)
